# %%
def gradf(x,y):
  return (6*x,2*y)

# %%
def f(x,y):
  return 3*x*x+y*y-200

# %%
x=5
y=5
lr=0.3
for i in range(20):
  g=gradf(x,y)
  x=x-lr*g[0]
  y=y-lr*g[1]
  print(x,y,f(x,y))
# Out:
# -4.0 2.0 -148.0
# 3.1999999999999993 0.8 -168.64000000000001
# -2.5599999999999996 0.32000000000000006 -180.23680000000002
# 2.047999999999999 0.12800000000000003 -187.40070400000002
# -1.638399999999999 0.05120000000000001 -191.94431488
# 1.310719999999999 0.020480000000000005 -194.8456198144
# -1.0485759999999993 0.008192000000000003 -196.701398007808
# 0.8388607999999993 0.0032768000000000016 -197.88892693725185
# -0.6710886399999996 0.001310720000000001 -198.64891839380192
# 0.5368709119999995 0.0005242880000000004 -199.13530859666696
# -0.4294967295999995 0.00020971520000000014 -199.44659763380824
# 0.3435973836799997 8.388608000000006e-05 -199.6458225067479
# -0.2748779069439997 3.3554432000000026e-05 -199.77332640769635
# 0.21990232555519973 1.342177280000001e-05 -199.8549289014661
# -0.17592186044415975 5.368709120000004e-06 -199.90715449702478
# 0.14073748835532784 2.147483648000002e-06 -199.94057887810968
# -0.11258999068426229 8.589934592000008e-07 -199.9619704819924
# ...
